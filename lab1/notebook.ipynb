# %% [markdown]
# # Modele liniowe

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Na początek ustawimy globalnie opcję `set_output` ze Scikit-learn'a ([dokumentacja](https://scikit-learn.org/stable/auto_examples/miscellaneous/plot_set_output.html)). Dzięki temu transformowane dane będą zawsze na wyjściu typu `pd.DataFrame`, zamiast `np.ndarray`, i zachowają odpowiednie nazwy cech.

# %%
import sklearn

sklearn.set_config(transform_output="pandas")

# %% [markdown]
# ## Przewidywanie cen domów

# %% [markdown]
# Wykorzystamy zbiór danych [Ames housing](https://www.openintro.org/book/statdata/?data=ames), w którym zadaniem jest przewidywanie wartości domu na podstawie cech budynku, działki, lokalizacji itp. Jest to więc przewidywanie wartości ciągłej, czyli regresja. Obejmuje zmienne do usunięcia (np. ID transakcji), numeryczne (floaty i inty), kategoryczne nieuporządkowane (*categorical nominal*) oraz kategoryczne uporządkowane (*categorical ordinal*), więc będzie wymagał wstępnego przetworzenia tak jak większość prawdziwych danych w ML.
#
# Inne znane, ale gorsze jakościowo zbiory tego typu to na przykład:
# - Boston housing - rasistowski, z tego powodu usunięty np. ze Scikit-learn ([wyjaśnienie](https://fairlearn.org/main/user_guide/datasets/boston_housing_data.html), [dyskusja](https://github.com/quantumblacklabs/causalnex/issues/92), [badanie](https://medium.com/@docintangible/racist-data-destruction-113e3eff54a8))
# - California housing - zbyt prosty (tylko kilka zmiennych numerycznych), użyty np. w książce "Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow" A. Geron ([opis](https://inria.github.io/scikit-learn-mooc/python_scripts/datasets_california_housing.html))
#
# Autor zbioru to Dean De Cock, a zbiór został opisany oryginalnie w [tym artykule](https://jse.amstat.org/v19n3/decock.pdf). Szczegółowe opisy zmiennych znajdują się w pliku `ames_description.txt`.
#
# Formatem pliku jest **Apache Parquet**, bardzo wydajny format binarny. Ma on szereg zalet w ML i inżynierii danych porównaniu do plików CSV:
# - zapisuje informacje o typie kolumn
# - jednoznaczna specyfikacja (np. brak problemów z typem separatora, jak w CSV)
# - kompresja liczb, napisów etc. w oparciu o ich typ
# - znacznie mniejszy rozmiar plików, zwykle kilka razy
# - dużo większa szybkość zapisu i odczytu
#
# Dla zainteresowanych szczegółami: [link 1](https://www.databricks.com/glossary/what-is-parquet#:~:text=Apache%20Parquet%20is%20an%20open,handle%20complex%20data%20in%20bulk.), [link 2](https://data-mozart.com/parquet-file-format-everything-you-need-to-know/), [link 3](https://learncsdesigns.medium.com/understanding-apache-parquet-d722645cfe74). Ten format ma szerokie wsparcie, w tym w Pandasie. W przypadku tego zbioru, CSV zajmuje ~1.2 MB, a Parquet ~0.2 MB.

# %%
df = pd.read_parquet("ames_data.parquet")

# remove dots from names to match data_description.txt
df.columns = [col.replace(".", "") for col in df.columns]

df.head()
# Out:
#    Order        PID  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0      1  526301100          20       RL        141.0    31770   Pave  None
# 1      2  526350040          20       RH         80.0    11622   Pave  None
# 2      3  526351010          20       RL         81.0    14267   Pave  None
# 3      4  526353030          20       RL         93.0    11160   Pave  None
# 4      5  527105010          60       RL         74.0    13830   Pave  None
#
#   LotShape LandContour  ... PoolArea PoolQC  Fence MiscFeature MiscVal MoSold  \
# 0      IR1         Lvl  ...        0   None   None        None       0      5
# 1      Reg         Lvl  ...        0   None  MnPrv        None       0      6
# 2      IR1         Lvl  ...        0   None   None        Gar2   12500      6
# 3      Reg         Lvl  ...        0   None   None        None       0      4
# 4      IR1         Lvl  ...        0   None  MnPrv        None       0      3
#
#   YrSold SaleType  SaleCondition  SalePrice
# 0   2010      WD          Normal     215000
# 1   2010      WD          Normal     105000
# 2   2010      WD          Normal     172000
# 3   2010      WD          Normal     244000
# 4   2010      WD          Normal     189900
#
# [5 rows x 82 columns]

# %%
df.shape
# Out:
# (2930, 82)

# %% [markdown]
# ## Eksploracja danych, czyszczenie danych i inżynieria cech

# %% [markdown]
# Wstępne czyszczenie danych (*data cleaning*) obejmuje:
# - usunięcie kolumn `Order` oraz `PID`
# - usunięcie obserwacji odstających (*outliers*), które mają powyżej 4000 stóp kwadratowych (ok. 370 metrów kwadratowych) powierzchni
# - usunięcie wpisów z dzielnic `GrnHill` oraz `Landmrk`, które obejmują w sumie zaledwie 3 domy
# - transformacja logarytmiczna zmiennej zależnej (ceny domu)
#
# To drugie jest motywowane wykresem przedstawionym poniżej. Zostało uznane za błąd już przez samego autora.

# %%
df = df.drop(["Order", "PID"], axis="columns")
df = df.loc[~df["Neighborhood"].isin(["GrnHill", "Landmrk"]), :]

plt.scatter(df["GrLivArea"], df["SalePrice"])
plt.title("House area vs price")
plt.xlabel("GrLivArea")
plt.ylabel("SalePrice")
plt.show()

df = df.loc[df["GrLivArea"] <= 4000, :]

plt.scatter(df["GrLivArea"], df["SalePrice"])
plt.title("House area vs price, outliers removed")
plt.xlabel("GrLivArea")
plt.ylabel("SalePrice")
plt.show()

# %% [markdown]
# Zawsze warto też przyjrzeć się rozkładowi zmiennej docelowej, żeby poznać jego typ i skalę. Jak widać poniżej, rozkład jest dość skośny, co ma sens - mało jest bardzo drogich domów. Można to zatem uznać za problem **regresji niezbalansowanej (imbalanced regression)**, w którym rozkład zmiennej docelowej nie jest normalny.
#
# Załóżmy, że typowego klienta nie interesują bardzo drogie domy. Cały ciężki ogon rozkładu można zatem uznać zasadniczo za outliery - im większa wartość, tym mniej interesuje przeciętną osobę. Warto też pamiętać, że realny "przeciętny" dochód to mediana, a nie średnia zarobków, co odpowiednio przekłada się na zainteresowanie domami.
#
# W tym przypadku warto przetransformować tę zmienną logarytmem bliżej rozkładu normalnego z dwóch powodów.
#
# Po pierwsze, stabilność numeryczna - wartości są bardzo duże, rzędu setek tysięcy, i przy obliczaniu odchylenia standardowego czy wariancji to byłby problem. Logarytm to przykład **transformacji stabilizującej wariancję (variance-stabilizing transform)**.
#
# Ponadto regresja liniowa (pierwszy model liniowy, który będziemy rozważać) czyni szereg założeń w modelowaniu, co wynika z jej podstaw statystycznych. Są to między innymi:
# 1. **Normalność błędów (residuals normality)** - błędy modelu, czyli $y - \hat{y}$, mają rozkład normalny
# 2. **Homoskedastyczność (homoscedasticity)** - błędy mają stałą wariancję, czyli nie zależą od wielkości zmiennej zależnej
#
# W naszym przypadku oznacza to, że podobnie często nie doceniamy albo przeceniamy wartość domu, oraz dla tanich i drogich domów mamy podobny błąd. Przy rozkładzie zmiennej zależnej bardzo różnym od normalnego te założenia są typowo łamane, co skutkuje gorszą jakością predykcji modelu. Dlatego transformacji warto też dokonać dla lepszej jakości modelu.
#
# Skąd wiemy, że logarytm? Bo rozkłady o dodaniej skośności (positively skewed) przesuwa się "w prawo" właśnie logarytmem, a w drugą stronę eksponentą. Dla zainteresowanych: [link 1](https://www.biostathandbook.com/transformation.html), [link 2](https://bookdown.org/dereksonderegger/571/8-LogTransformations-Chapter.html). Są też algorytmy, które potrafią same estymować potrzebną transformację, np. **Box-Cox transform** albo **Yeo-Johnson transform**. Podobne transformacje można też oczywiście wykonywać nie tylko dla zmiennej zależnej, ale też (a nawet jest to częstsze) dla cech.
#
# **Zadanie 1 (1 punkt)**
#
# 1. Narysuj wykres cen - histogram kolumny `"SalePrice"`. Pamiętaj o podaniu tytułu i dodaniu legendy.
# 2. Oblicz średnią i medianę cen, a następnie nanieś je na wykres jako pionowe, przerywane linie. Może się przydać [ten przykład](https://stackoverflow.com/a/57046310/9472066). Wypisz te wartości, lub zawrzyj je w opisie w legendzie, zaokrąglone do liczb całkowitych.
# 3. Zlogarytmuj ceny z pomocą `np.log1p` (zamień istniejące wartości).
# 4. Narysuj wykres po zlogarytmowaniu, razem z liniami dla średniej i mediany.
#
# Może ci się przydać metoda `.plot.hist()` dla `pd.Series`. Zwraca ona normalny wykres Matplotliba, do którego można potem dodawać kolejne elementy.

# %%
prices = df['SalePrice']
prices = prices.apply(np.log1p)
df['SalePrice'] = prices

plot = prices.plot.hist()
plot.axvline(prices.mean(), color='orange', linestyle='dashed')
plot.axvline(prices.median(), color='red', linestyle='dashed')

# %% [markdown]
# W zbiorze znajdują się liczne wartości brakujące, które zostały uzupełnione na podstawie [tego notebooka na Kaggle](https://www.kaggle.com/code/juliencs/a-study-on-regression-applied-to-the-ames-dataset).

# %%
def replace_na(df: pd.DataFrame, col: str, value) -> None:
    df.loc[:, col] = df.loc[:, col].fillna(value)


# Alley : data description says NA means "no alley access"
replace_na(df, "Alley", value="None")

# BedroomAbvGr : NA most likely means 0
replace_na(df, "BedroomAbvGr", value=0)

# BsmtQual etc : data description says NA for basement features is "no basement"
replace_na(df, "BsmtQual", value="No")
replace_na(df, "BsmtCond", value="No")
replace_na(df, "BsmtExposure", value="No")
replace_na(df, "BsmtFinType1", value="No")
replace_na(df, "BsmtFinType2", value="No")
replace_na(df, "BsmtFullBath", value=0)
replace_na(df, "BsmtHalfBath", value=0)
replace_na(df, "BsmtUnfSF", value=0)

# Condition : NA most likely means Normal
replace_na(df, "Condition1", value="Norm")
replace_na(df, "Condition2", value="Norm")

# External stuff : NA most likely means average
replace_na(df, "ExterCond", value="TA")
replace_na(df, "ExterQual", value="TA")

# Fence : data description says NA means "no fence"
replace_na(df, "Fence", value="No")

# Functional : data description says NA means typical
replace_na(df, "Functional", value="Typ")

# GarageType etc : data description says NA for garage features is "no garage"
replace_na(df, "GarageType", value="No")
replace_na(df, "GarageFinish", value="No")
replace_na(df, "GarageQual", value="No")
replace_na(df, "GarageCond", value="No")
replace_na(df, "GarageArea", value=0)
replace_na(df, "GarageCars", value=0)

# HalfBath : NA most likely means no half baths above grade
replace_na(df, "HalfBath", value=0)

# HeatingQC : NA most likely means typical
replace_na(df, "HeatingQC", value="Ta")

# KitchenAbvGr : NA most likely means 0
replace_na(df, "KitchenAbvGr", value=0)

# KitchenQual : NA most likely means typical
replace_na(df, "KitchenQual", value="TA")

# LotFrontage : NA most likely means no lot frontage
replace_na(df, "LotFrontage", value=0)

# LotShape : NA most likely means regular
replace_na(df, "LotShape", value="Reg")

# MasVnrType : NA most likely means no veneer
replace_na(df, "MasVnrType", value="None")
replace_na(df, "MasVnrArea", value=0)

# MiscFeature : data description says NA means "no misc feature"
replace_na(df, "MiscFeature", value="No")
replace_na(df, "MiscVal", value=0)

# OpenPorchSF : NA most likely means no open porch
replace_na(df, "OpenPorchSF", value=0)

# PavedDrive : NA most likely means not paved
replace_na(df, "PavedDrive", value="N")

# PoolQC : data description says NA means "no pool"
replace_na(df, "PoolQC", value="No")
replace_na(df, "PoolArea", value=0)

# SaleCondition : NA most likely means normal sale
replace_na(df, "SaleCondition", value="Normal")

# ScreenPorch : NA most likely means no screen porch
replace_na(df, "ScreenPorch", value=0)

# TotRmsAbvGrd : NA most likely means 0
replace_na(df, "TotRmsAbvGrd", value=0)

# Utilities : NA most likely means all public utilities
replace_na(df, "Utilities", value="AllPub")

# WoodDeckSF : NA most likely means no wood deck
replace_na(df, "WoodDeckSF", value=0)

# CentralAir : NA most likely means No
replace_na(df, "CentralAir", value="N")

# EnclosedPorch : NA most likely means no enclosed porch
replace_na(df, "EnclosedPorch", value=0)

# FireplaceQu : data description says NA means "no fireplace"
replace_na(df, "FireplaceQu", value="No")
replace_na(df, "Fireplaces", value=0)

# SaleCondition : NA most likely means normal sale
replace_na(df, "SaleCondition", value="Normal")

# Electrical : NA most likely means standard circuit & breakers
replace_na(df, "Electrical", value="SBrkr")

# %% [markdown]
# W dalszej kolejności zamienimy zmienne `MSSubClass` i `MoSold` z numerycznych na kategoryczne, zgodnie z ich znaczeniem. Zakodujemy także zmienne kategoryczne uporządkowane (categorical ordinal) z tekstowych na kolejne liczby całkowite.

# %%
df = df.replace(
    {
        "MSSubClass": {
            20: "SC20",
            30: "SC30",
            40: "SC40",
            45: "SC45",
            50: "SC50",
            60: "SC60",
            70: "SC70",
            75: "SC75",
            80: "SC80",
            85: "SC85",
            90: "SC90",
            120: "SC120",
            150: "SC150",
            160: "SC160",
            180: "SC180",
            190: "SC190",
        },
        "MoSold": {
            1: "Jan",
            2: "Feb",
            3: "Mar",
            4: "Apr",
            5: "May",
            6: "Jun",
            7: "Jul",
            8: "Aug",
            9: "Sep",
            10: "Oct",
            11: "Nov",
            12: "Dec",
        },
    }
)

# %%
df = df.replace(
    {
        "Alley": {"None": 0, "Grvl": 1, "Pave": 2},
        "BsmtCond": {"No": 0, "Po": 1, "Fa": 2, "TA": 3, "Gd": 4, "Ex": 5},
        "BsmtExposure": {"No": 0, "Mn": 1, "Av": 2, "Gd": 3},
        "BsmtFinType1": {
            "No": 0,
            "Unf": 1,
            "LwQ": 2,
            "Rec": 3,
            "BLQ": 4,
            "ALQ": 5,
            "GLQ": 6,
        },
        "BsmtFinType2": {
            "No": 0,
            "Unf": 1,
            "LwQ": 2,
            "Rec": 3,
            "BLQ": 4,
            "ALQ": 5,
            "GLQ": 6,
        },
        "BsmtQual": {"No": 0, "Po": 1, "Fa": 2, "TA": 3, "Gd": 4, "Ex": 5},
        "ExterCond": {"Po": 1, "Fa": 2, "TA": 3, "Gd": 4, "Ex": 5},
        "ExterQual": {"Po": 1, "Fa": 2, "TA": 3, "Gd": 4, "Ex": 5},
        "FireplaceQu": {"No": 0, "Po": 1, "Fa": 2, "TA": 3, "Gd": 4, "Ex": 5},
        "Functional": {
            "Sal": 1,
            "Sev": 2,
            "Maj2": 3,
            "Maj1": 4,
            "Mod": 5,
            "Min2": 6,
            "Min1": 7,
            "Typ": 8,
        },
        "GarageCond": {"No": 0, "Po": 1, "Fa": 2, "TA": 3, "Gd": 4, "Ex": 5},
        "GarageQual": {"No": 0, "Po": 1, "Fa": 2, "TA": 3, "Gd": 4, "Ex": 5},
        "HeatingQC": {"Po": 1, "Fa": 2, "TA": 3, "Gd": 4, "Ex": 5},
        "KitchenQual": {"Po": 1, "Fa": 2, "TA": 3, "Gd": 4, "Ex": 5},
        "LandSlope": {"Sev": 1, "Mod": 2, "Gtl": 3},
        "LotShape": {"IR3": 1, "IR2": 2, "IR1": 3, "Reg": 4},
        "PavedDrive": {"N": 0, "P": 1, "Y": 2},
        "PoolQC": {"No": 0, "Fa": 1, "TA": 2, "Gd": 3, "Ex": 4},
        "Street": {"Grvl": 1, "Pave": 2},
        "Utilities": {"ELO": 1, "NoSeWa": 2, "NoSewr": 3, "AllPub": 4},
    }
)
# Out:
# /tmp/ipykernel_8343/3839597250.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(

# %% [markdown]
# W Pandasie zmienne kategoryczne, napisy itp. są typu `object`, natomiast numeryczne mają typy z Numpy'a, np. `int64`. Oczywiście oba rodzaje zmiennych trzeba przetwarzać na inne sposoby, więc zapiszemy to od razu. Wyodrębnimy też wektor docelowy.
#
# Od razu dokonamy też podziału na zbiór treningowy i testowy. Jako że nasz zbiór jest dość mały, to podział będzie 70%-30%.

# %%
from sklearn.model_selection import train_test_split

y = df.pop("SalePrice")

categorical_features = df.select_dtypes(include="object").columns
numerical_features = df.select_dtypes(exclude="object").columns

X_train_raw, X_test_raw, y_train, y_test = train_test_split(
    df, y, test_size=0.3, random_state=0
)

# %% [markdown]
# ## Analiza i przetwarzanie cech

# %% [markdown]
# Modele liniowe działają najlepiej, kiedy nasze cechy są odpowiednio przetworzone:
# - nie może być wartości brakujących
# - wszystkie zmienne mają podobny zakres wartości
# - nie ma mocno skorelowanych ze sobą cech
# - zmienne kategoryczne muszą być zakodowane, przy czym dobrze jest, kiedy cech nie jest zbyt dużo
#
# Na start imputujemy wartości brakujące w zmiennych numerycznych i przeskalujemy je do zakresu $[0, 1]$. Potem dokonamy analizy, czy mamy mocno skorelowane zmienne.
#
# Przy przetwarzaniu danych krok po kroku lepiej robić nowe zmienne, żeby dało się odpalić znowu komórkę notebooka. Przy reużywaniu zmiennych mogłaby nastąpić konieczność uruchomienia wszystkiego od początku. Może ci się to przydać w zadaniach.
#
# Pamiętaj, żeby we wszystkich kolejnych zadaniach zastosować taką samą transformację na zbiorze treningowym i testowym. Wszelkie wartości estymujemy na zbiorze treningowym.
#
# **Zadanie 2 (0.5 punktu)**
#
# Wybierz same zmienne numeryczne. Dokonaj imputacji wartości brakujących medianą, oraz przeskaluj wartości do zakresu $[0, 1]$. Przydatne klasy: `ColumnTransformer`, `Pipeline`, `SimpleImputer`, `MinMaxScaler`.
#
# Domyślnie `ColumnTransformer` dopisuje do nazw cech wyjściowych nazwę transformera jako prefix. Bywa to dość nieczytelne i problematyczne w dalszym przetwarzaniu danych. Żeby to wyłączyć, przekaż opcję `verbose_feature_names_out=False`.

# %%
import sklearn.impute
import sklearn.preprocessing


inputer = sklearn.impute.SimpleImputer(missing_values=np.nan, strategy='median')
scaler = sklearn.preprocessing.MinMaxScaler()

X_train_num = X_train_raw.select_dtypes(include=['number'])
X_test_num = X_test_raw.select_dtypes(include=['number'])

inputer.fit(X_train_num)
scaler.fit(X_train_num)

X_train_num = inputer.transform(X_train_num)
X_test_num = inputer.transform(X_test_num)

X_train_num = scaler.transform(X_train_num)
X_test_num = scaler.transform(X_test_num)

# %% [markdown]
# Sprawdźmy teraz, czy mamy mocno skorelowane zmienne. Typowo przyjmuje się wartość bezwzględną korelacji powyżej progu 0.8/0.9/0.95. Pierwszą weryfikację można zrobić "na oko" na podstawie wykresu typu heatmap. Przekątną oczywiście ignorujemy - każda cecha ma korelację 1.0 z samą sobą.
#
# Jeżeli zauważymy grupy skorelowanych cech, to z każdej grupy trzeba zostawić jedną cechę. Biblioteka Feature-engine, komplatybilna ze Scikie-learn, oferuje tutaj wygodną klasę `SmartCorrelatedSelection`, która pozwala z każdej grupy cech zostawić tę o największej wariancji.
#
# Czemu o największej wariancji? Bo taka cecha jest mocno zmienna, a więc niesie jakąś informację. Cechy o bardzo niskiej wariancji praktycznie się nie zmieniają, więc prawdopodobnie nie są zbyt informatywne.
#
# **Zadanie 3 (0.5 punktu)**
#
# Oblicz korelacje między cechami w zbiorze treningowym, oraz narysuj heatmapę korelacji. Pandas potrafi obliczyć korelacje, a Seaborn - narysować wygodnie heatmapę.
#
# Następnie wykorzystaj Feature-engine do eliminacji mocno skorelowanych cech, z progiem 0.8 (mamy sporo cech, więc eliminujmy, czemu nie), pozostawiając cechy o największej wariancji. Wypisz nazwy wyeliminowanych cech.

# %%
import seaborn as sns
import feature_engine.selection as fes

corr = X_train_num.corr()
sns.heatmap(corr)

selector = fes.SmartCorrelatedSelection(
    variables=None,
    method="pearson",
    threshold=0.8,
    missing_values="raise",
    selection_method="variance",
    estimator=None,
)

selector.fit(X_train_num)

X_train_num = selector.transform(X_train_num)
X_test_num = selector.transform(X_test_num)

print(set(X_train_raw.select_dtypes(include=['number']).columns) - set(X_train_num.columns))
# Out:
# {'GarageArea', 'TotRmsAbvGrd', 'PoolQC', 'GarageCond', 'BsmtFinSF2', 'Fireplaces'}

# %% [markdown]
# Przejdźmy teraz do zmiennych kategorycznych. Jeżeli pewne kategorie występują bardzo rzadko, to prawdopodobnie nie ma sensu ich rozróżniać, i można by je połączyć w jedną, np. "Other" albo "Rare". Eliminacja rzadkich kategorii bardzo zmniejszy wymiarowość po one-hot encodingu, redukując złożoność obliczeniową i pamięciową. Często robi się to nawet głównie z tego powodu, nawet jeżeli lekko pogorszy to wyniki (aczkolwiek często daje nieco lepsze).
#
# Po tym kroku możemy już wykonać one-hot encoding i uzyskać nasze zmienne kategoryczne.
#
# **Zadanie 4 (0.5 punktu)**
#
# Stwórz `ColumnTransformer`, wykonujący w pipeline'ie dla zmiennych kategorycznych (analogicznie jak w zadaniu 1 dla zmiennych numerycznych):
# - łączenie rzadkich kategorii (występujących w mniej niż 1% wierszy) w kategorię "Rare"
# - one-hot encoding
#
# Dla uniknięcia dummy variable trap, oraz zmniejszenia liczby wynikowych cech, podaj `drop="first"` w one-hot encodingu.
#
# Przyda się `RareLabelEncoder` z Feature-engine. Żeby zadziałał dla każdej cechy, podaj mu `n_categories=0`.

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from feature_engine.encoding import RareLabelEncoder
from sklearn.preprocessing import OneHotEncoder


cat_cols = X_train_raw.select_dtypes(exclude=['number']).columns.tolist()

cat_pipeline = Pipeline([
    ("rare", RareLabelEncoder(tol=0.01, n_categories=0, replace_with="Rare")),
    ("onehot", OneHotEncoder(drop="first", sparse_output=False, handle_unknown="ignore"))
])

preprocessor = ColumnTransformer([
    ("trans_cat", cat_pipeline, cat_cols)
])

X_train_cat = preprocessor.fit_transform(X_train_raw)
X_test_cat = preprocessor.transform(X_test_raw)

# %% [markdown]
# Teraz nasze cechy są w pełni przeprocesowane i gotowe do obliczeń. Trzeba je tylko połączyć - zmodyfikuj kod poniżej w zależności od nazw twoich zmiennych.

# %%
# X_train_num = ...
# X_test_num = ...

# X_train_cat = ...
# X_test_cat = ...

X_train = pd.concat([X_train_num, X_train_cat], axis=1)
X_test = pd.concat([X_test_num, X_test_cat], axis=1)

# %%
X_train.shape
# Out:
# (2045, 175)

# %% [markdown]
# ## Regresja liniowa, ridge i LASSO

# %% [markdown]
# Naszym baseline'owym modelem liniowym, do którego będziemy odnosić bardziej złożone modele, będzie zwykła **regresja liniowa (linear regression)**
#
# Naszymi metrykami będą zarówno **pierwiastek błędu średniokwadratowego (root mean squared error, RMSE)**, jak i **średni błąd bezwzględny (mean absolute error)**. Oba są w tej samej jednostce, co oryginalna zmienna zależna, ale skupiają się na innych rzeczach:
# - RMSE bardziej uwzględni predykcje w ogonie, czyli drogie domy
# - MAE bardziej skupi się na przeciętnym przypadku, czyli cenach bliżej mediany
#
# W praktyce często interesuje nas kilka metryk, a mamy dużo modeli do sprawdzanie. Żeby nie kopiować kodu, warto zrobić funkcję, obliczającą i wypisującą metryki dla danego problemu. Dodatkowo tutaj musimy odwrócić logarytm, który zastosowaliśmy na początku, i takie odwrotne przekształcenia też dobrze jest zawrzeć w takiej funkcji.

# %%
from sklearn.metrics import root_mean_squared_error, mean_absolute_error


def evaluate_model(
    y_train: np.ndarray,
    y_test: np.ndarray,
    y_pred_train: np.ndarray,
    y_pred_test: np.ndarray,
) -> None:
    y_train = np.expm1(y_train)
    y_test = np.expm1(y_test)

    y_pred_train = np.expm1(y_pred_train)
    y_pred_test = np.expm1(y_pred_test)

    rmse_train = root_mean_squared_error(y_train, y_pred_train)
    mae_train = mean_absolute_error(y_train, y_pred_train)

    rmse_test = root_mean_squared_error(y_test, y_pred_test)
    mae_test = mean_absolute_error(y_test, y_pred_test)

    print(f"Train RMSE {rmse_train:.2f}, MAE: {mae_train:.2f}")
    print(f"Test  RMSE {rmse_test:.2f}, MAE: {mae_test:.2f}")

# %% [markdown]
# Jesteśmy teraz gotowi na trening naszych modeli. Na start wytrenujmy zwykłą regresję liniową.

# %%
from sklearn.linear_model import LinearRegression

reg_linear = LinearRegression()
reg_linear.fit(X_train, y_train)

y_pred_train = reg_linear.predict(X_train)
y_pred_test = reg_linear.predict(X_test)


evaluate_model(y_train, y_test, y_pred_train, y_pred_test)
# Out:
# Train RMSE 17643.38, MAE: 12163.00
# Test  RMSE 18695.21, MAE: 13107.66

# %% [markdown]
# Całkiem nieźle. Dla porównania, bez usuwania skorelowanych cech i grupowania rzadkich cech, RMSE na zbiorze testowym to ponad 21 tysięcy, a model wyraźnie przeucza. Warto wykonywać odpowiedni preprocessing danych!
#
# Mamy tu wyraźną różnicę między RMSE i MAE. Można się temu przyjrzeć i przeanalizować rozkład **rezyduów (residuals)**, czyli błędów $y - \hat{y}$.
#
# **Zadanie 5 (0.5 punktu)**
#
# Narysuj rozkład błędów popełnianych przez model regresji liniowej. Pamiętaj o odwróceniu logarytmu eksponentą (`np.expm1`). Dobierz liczbę binów histogramu tak, żeby wykres był odpowiednio czytelny. Zaznacz liniami pionowymi średnią oraz medianę. Pamiętaj o opisaniu osi Y, legendzie i tytule.
#
# Skomentuj rozkład. Jest symetryczny? Może częściej nie doceniamy wartości domu, albo ją przeceniamy, albo może są tu jakiejś pojedyncze outliery? Czy na podstawie tych rezyduów można wytłumaczyć różnicę między MAE i RMSE?

# %%
import numpy as np
import matplotlib.pyplot as plt

y_test_exp = np.expm1(y_test)
y_pred_test_exp = np.expm1(y_pred_test)

residuals = y_test_exp - y_pred_test_exp

mean_res = np.mean(residuals)
median_res = np.median(residuals)

plt.figure(figsize=(10, 6))
plt.hist(residuals, bins=50, edgecolor='black')

plt.axvline(mean_res, color='red', linestyle='-', linewidth=2, label=f'Średnia: {mean_res:.0f}')
plt.axvline(median_res, color='orange', linestyle='--', linewidth=2, label=f'Mediana: {median_res:.0f}')

plt.title('Rozkład błędów predykcji (rezyduów) regresji liniowej')
plt.xlabel('Błąd predykcji (y_test - y_pred)')
plt.ylabel('Liczba obserwacji')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Rozkład jest dosyć symetryczny chociaż istnieją bardzo niedoszacowane outliery.
# Tak na tej podstawie można wytłumaczyć różnice pomiędzy `MAE` i `RMSE` ponieważ jest zauważalna grupa domów przeszacowanych lub niedoszacowanych o minimum `50 000`, a `RMSE` jest bardziej wrażliwe na skrajne wyniki więc to tłumaczy jego większą wartość

# %% [markdown]
# Mamy pewien overfitting - co prawda niewielki, ale zawsze jest coś do wyeliminowania. Dodatkowo mamy aż 175 cech - jeżeli niektóre z nich mają bardzo niską moc predykcyjną, to redukcja ich wag (lub ich usunięcie) może poprawić nawet i wynik treningowy, i testowy, bo zredukuje szum.
#
# Warto każdy model zapisywać w zmiennej o innej nazwie, żeby później móc dokonać ich porównania. Przykładowo, `reg_linear` czy `reg_ridge` jest lepszym pomysłem niż samo `reg`.
#
# Typowo siłę regularyzacji wybiera się tak, że najpierw szacujemy rząd wielkości, sprawdzając np. siatkę `[1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3]`, a później zagęszczając ją w okolicy znalezionej optymalnej wartości. Można to oczywiście robić w kilku krokach.
#
# **Zadanie 6 (1 punkt)**
#
# Wytrenuj modele z regularyzacją L2 (ridge) oraz L1 (LASSO). Dobierz siłę regularyzacji, najpierw estymując rząd wielkości, a potem zagęszczając siatkę. Dla regresji ridge wybieraj model o optymalnym MAE (argument `scoring`). Zmierz czas tuningu podczas drugiego kroku, po zagęszczeniu siatki.
#
# Wypisz optymalne hiperparametry dla obu modeli, oraz ich metryki jakości.
#
# Przydadzą się `np.linspace()`, `RidgeCV` oraz `LassoCV`.

# %%
import time
from sklearn.linear_model import RidgeCV, LassoCV
from sklearn.metrics import mean_absolute_error

alphas_range = np.linspace(1e-6, 1e2, 100)

ridge_model = RidgeCV(alphas=alphas_range, store_cv_values=True)

start_time = time.time()
ridge_model.fit(X_train_num, y_train)
ridge_time = time.time() - start_time

print(f"Ridge - Optymalny alpha: {ridge_model.alpha_}")
print(f"Ridge - MAE: {mean_absolute_error(y_train, ridge_model.predict(X_train_num)):.2f}")
print(f"Czas tuningu Ridge: {ridge_time:.2f} sekund")

lasso_model = LassoCV(alphas=alphas_range, cv=5, max_iter=10000)

start_time = time.time()
lasso_model.fit(X_train_num, y_train)
lasso_time = time.time() - start_time

print(f"Lasso - Optymalny alpha: {lasso_model.alpha_}")
print(f"Lasso - MAE: {mean_absolute_error(y_train, lasso_model.predict(X_train_num)):.2f}")
print(f"Czas tuningu Lasso: {lasso_time:.2f} sekund")
# Out:
# Ridge - Optymalny alpha: 1.0101019999999998
# Ridge - MAE: 0.09
# Czas tuningu Ridge: 0.06 sekund
# Lasso - Optymalny alpha: 1e-06
# Lasso - MAE: 0.09
# Czas tuningu Lasso: 0.10 sekund
# /home/hubert/podstawy-uczenia-maszynowego-24-25/.venv/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:2385: FutureWarning: 'store_cv_values' is deprecated in version 1.5 and will be removed in 1.7. Use 'store_cv_results' instead.
#   warnings.warn(

# %% [markdown]
# Dużą zaletą modeli liniowych jest możliwość analizy ważności cech oraz ich kierunku wpływu. W przypadku regresji z regularyzacją jest to szczególnie ciekawe.
#
# Jeżeli cecha "przetrwa" z dużą wagą w ridge regression, to znaczy, że musi być naprawdę ważna, bo inaczej opłacałoby się zmniejszyć jej wagę, żeby zmniejszyć koszt z regularyzacji. Z drugiej strony, w regresji LASSO jeżeli cecha została wyeliminowana, to musiała mieć na tyle małą moc predykcyjną, że modelowi bardziej opłacało się ją usunąć i zmniejszyć koszt z regularyzacji.
#
# **Zadanie 7 (0.5 punktu)**
#
# W tym zadaniu skorzystaj z optymalnych modeli, wyznaczonych w poprzednim zadaniu.
#
# 1. Wybierz 20 najważniejszych cech według ridge regression (w sensie wartości bezwzględnej ich wag). Przedstaw je na poziomym wykresie słupkowym (horizontal bar plot), posortowane według wartości bezwzględnej. Na wykresie mają być wartości wag z wpływem (dodatni/ujemny). Pamiętaj o opisaniu osi nazwami cech i tytule wykresu.
# 2. Wypisz nazwy cech wyeliminowanych przez LASSO regression, posortowane alfabetycznie. Zakładamy, że cecha jest wyeliminowana, jeżeli dla `np.isclose()` jej waga jest bliska zeru.
#
# Mogą się przydać atrybuty modelu `.coef_` oraz `.feature_names_in_`. Wszystkie operacje można łatwo wykonać, konwertując dane na `pd.Series`.

# %%
ridge_coef = pd.Series(ridge_model.coef_, index=ridge_model.feature_names_in_).abs().sort_values(ascending=False).head(20)

plt.figure(figsize=(10, 6))
ridge_coef.plot(kind='barh')
plt.title('Top 20 najważniejszych cech według Ridge Regression')
plt.xlabel('Waga cechy')
plt.ylabel('Nazwa cechy')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Robust regression

# %% [markdown]
# Powyższe algorytmy nie brały pod uwagę skośnego rozkładu zmiennej zależnej, oraz realnego zapotrzebowania na medianę ceny domu. Wypróbujmy zatem algorytmy, które powinny być bardziej odporne na outliery.
#
# Na start wypróbujemy Least Absolute Deviations (LAD) regression. Jako że jest to przypadek szczególny regresji kwantylowej, to w Scikit-learn używa się do tego klasy `QuantileRegressor` z podaniem odpowiedniego kwantyla.

# %%
from sklearn.linear_model import QuantileRegressor

reg_lad = QuantileRegressor(quantile=0.5)
reg_lad.fit(X_train, y_train)

y_pred_train = reg_lad.predict(X_train)
y_pred_test = reg_lad.predict(X_test)
evaluate_model(y_train, y_test, y_pred_train, y_pred_test)
# Out:
# Train RMSE 80520.69, MAE: 55705.73
# Test  RMSE 80920.80, MAE: 55734.18

# %% [markdown]
# Błąd jest wręcz tragiczny! W takich przypadkach zawsze na start trzeba się przyjrzeć predykcjom.

# %%
y_pred_test[:30]
# Out:
# array([11.99535779, 11.99535779, 11.99535779, 11.99535779, 11.99535779,
#        11.99535779, 11.99535779, 11.99535779, 11.99535779, 11.99535779,
#        11.99535779, 11.99535779, 11.99535779, 11.99535779, 11.99535779,
#        11.99535779, 11.99535779, 11.99535779, 11.99535779, 11.99535779,
#        11.99535779, 11.99535779, 11.99535779, 11.99535779, 11.99535779,
#        11.99535779, 11.99535779, 11.99535779, 11.99535779, 11.99535779])

# %% [markdown]
# Predykcje stałe - nic dziwnego, że błąd jest duży. Scikit-learn domyślnie stosuje lekką regularyzację dla wielu modeli, ale wartość ta może być zbyt duża.
#
# **Zadanie 8 (1 punkt)**
#
# Dokonaj tuningu siły regularyzacji dla LAD regression, sprawdzając 100 wartości z zakresu od 0 do `1e-3`. Wybierz model o najlepszym MAE z pomocą 5-fold CV. Zmierz czas tuningu, wypisz znalezione hiperparametry oraz sprawdź jakość finalnego modelu.
#
# Skomentuj różnicę czasową i jakościową względem modeli ridge i LASSO. Czy w tym przypadku warto wykorzystać regresję LAD?
#
# Przyda się `GridSearchCV` oraz parametr `n_jobs`.

# %%
from sklearn.model_selection import GridSearchCV
def grid_search(model : sklearn.linear_model, X_train, y_train):
    alphas = np.linspace(0, 1e-3, 100)
    params = {'quantile': [0.5], 
              "alpha" : alphas, 
              "solver" : ["highs"]}
    t = time()
    clf = GridSearchCV(model, params, n_jobs=-1, scoring='neg_mean_absolute_error', verbose = 2)
    clf.fit(X_train, y_train)
    print(f"fitting time: {time() - t}")
    return clf
    
clf = grid_search(QuantileRegressor(), X_train, y_train)
best_after_grid = clf.best_estimator_
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END ..............alpha=0.0, quantile=0.5, solver=highs; total time=  12.3s
# [CV] END ..............alpha=0.0, quantile=0.5, solver=highs; total time=  13.0s
# [CV] END ..............alpha=0.0, quantile=0.5, solver=highs; total time=  13.1s
# [CV] END ..............alpha=0.0, quantile=0.5, solver=highs; total time=  13.0s
# [CV] END ..............alpha=0.0, quantile=0.5, solver=highs; total time=  13.2s
# [CV] END alpha=1.0101010101010101e-05, quantile=0.5, solver=highs; total time=  13.2s
# [CV] END alpha=1.0101010101010101e-05, quantile=0.5, solver=highs; total time=  13.3s
# [CV] END alpha=1.0101010101010101e-05, quantile=0.5, solver=highs; total time=  13.5s
# [CV] END alpha=2.0202020202020203e-05, quantile=0.5, solver=highs; total time=  13.7s
# [CV] END alpha=1.0101010101010101e-05, quantile=0.5, solver=highs; total time=  14.5s
# [CV] END alpha=2.0202020202020203e-05, quantile=0.5, solver=highs; total time=  13.6s
# [CV] END alpha=2.0202020202020203e-05, quantile=0.5, solver=highs; total time=  14.1s
# [CV] END alpha=2.0202020202020203e-05, quantile=0.5, solver=highs; total time=  14.6s
# [CV] END alpha=1.0101010101010101e-05, quantile=0.5, solver=highs; total time=  14.8s
# [CV] END alpha=3.0303030303030306e-05, quantile=0.5, solver=highs; total time=  14.8s
# [CV] END alpha=2.0202020202020203e-05, quantile=0.5, solver=highs; total time=  15.4s
# [CV] END alpha=3.0303030303030306e-05, quantile=0.5, solver=highs; total time=  16.5s
# [CV] END alpha=3.0303030303030306e-05, quantile=0.5, solver=highs; total time=  16.4s
# [CV] END alpha=3.0303030303030306e-05, quantile=0.5, solver=highs; total time=  16.6s
# [CV] END alpha=4.0404040404040405e-05, quantile=0.5, solver=highs; total time=  16.8s
# [CV] END alpha=3.0303030303030306e-05, quantile=0.5, solver=highs; total time=  17.7s
# [CV] END alpha=4.0404040404040405e-05, quantile=0.5, solver=highs; total time=  16.7s
# [CV] END alpha=4.0404040404040405e-05, quantile=0.5, solver=highs; total time=  16.7s
# [CV] END alpha=4.0404040404040405e-05, quantile=0.5, solver=highs; total time=  17.4s
# [CV] END alpha=5.0505050505050505e-05, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=5.0505050505050505e-05, quantile=0.5, solver=highs; total time=  17.8s
# [CV] END alpha=5.0505050505050505e-05, quantile=0.5, solver=highs; total time=  18.7s
# [CV] END alpha=5.0505050505050505e-05, quantile=0.5, solver=highs; total time=  18.2s
# [CV] END alpha=4.0404040404040405e-05, quantile=0.5, solver=highs; total time=  19.8s
# [CV] END alpha=5.0505050505050505e-05, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=6.060606060606061e-05, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=6.060606060606061e-05, quantile=0.5, solver=highs; total time=  18.6s
# [CV] END alpha=6.060606060606061e-05, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=7.07070707070707e-05, quantile=0.5, solver=highs; total time=  18.5s
# [CV] END alpha=6.060606060606061e-05, quantile=0.5, solver=highs; total time=  19.4s
# [CV] END alpha=7.07070707070707e-05, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=7.07070707070707e-05, quantile=0.5, solver=highs; total time=  18.6s
# [CV] END alpha=6.060606060606061e-05, quantile=0.5, solver=highs; total time=  20.5s
# [CV] END alpha=7.07070707070707e-05, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=7.07070707070707e-05, quantile=0.5, solver=highs; total time=  21.3s
# [CV] END alpha=8.080808080808081e-05, quantile=0.5, solver=highs; total time=  16.6s
# [CV] END alpha=8.080808080808081e-05, quantile=0.5, solver=highs; total time=  16.2s
# [CV] END alpha=8.080808080808081e-05, quantile=0.5, solver=highs; total time=  17.2s
# [CV] END alpha=8.080808080808081e-05, quantile=0.5, solver=highs; total time=  17.1s
# [CV] END alpha=8.080808080808081e-05, quantile=0.5, solver=highs; total time=  16.8s
# [CV] END alpha=9.090909090909092e-05, quantile=0.5, solver=highs; total time=  16.8s
# [CV] END alpha=9.090909090909092e-05, quantile=0.5, solver=highs; total time=  17.0s
# [CV] END alpha=9.090909090909092e-05, quantile=0.5, solver=highs; total time=  17.2s
# [CV] END alpha=9.090909090909092e-05, quantile=0.5, solver=highs; total time=  16.5s
# [CV] END alpha=9.090909090909092e-05, quantile=0.5, solver=highs; total time=  16.6s
# [CV] END alpha=0.00010101010101010101, quantile=0.5, solver=highs; total time=  17.0s
# [CV] END alpha=0.00010101010101010101, quantile=0.5, solver=highs; total time=  17.4s
# [CV] END alpha=0.00010101010101010101, quantile=0.5, solver=highs; total time=  17.1s
# [CV] END alpha=0.00010101010101010101, quantile=0.5, solver=highs; total time=  17.3s
# [CV] END alpha=0.00010101010101010101, quantile=0.5, solver=highs; total time=  17.3s
# [CV] END alpha=0.00011111111111111112, quantile=0.5, solver=highs; total time=  18.0s
# [CV] END alpha=0.00011111111111111112, quantile=0.5, solver=highs; total time=  18.5s
# [CV] END alpha=0.00011111111111111112, quantile=0.5, solver=highs; total time=  18.4s
# [CV] END alpha=0.00011111111111111112, quantile=0.5, solver=highs; total time=  17.5s
# [CV] END alpha=0.00011111111111111112, quantile=0.5, solver=highs; total time=  18.6s
# [CV] END alpha=0.00012121212121212122, quantile=0.5, solver=highs; total time=  18.7s
# [CV] END alpha=0.00012121212121212122, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.00012121212121212122, quantile=0.5, solver=highs; total time=  18.7s
# [CV] END alpha=0.00012121212121212122, quantile=0.5, solver=highs; total time=  19.5s
# [CV] END alpha=0.00012121212121212122, quantile=0.5, solver=highs; total time=  18.5s
# [CV] END alpha=0.00013131313131313133, quantile=0.5, solver=highs; total time=  18.6s
# [CV] END alpha=0.00013131313131313133, quantile=0.5, solver=highs; total time=  18.4s
# [CV] END alpha=0.00013131313131313133, quantile=0.5, solver=highs; total time=  19.4s
# [CV] END alpha=0.0001414141414141414, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.00013131313131313133, quantile=0.5, solver=highs; total time=  20.6s
# [CV] END alpha=0.00013131313131313133, quantile=0.5, solver=highs; total time=  20.6s
# [CV] END alpha=0.0001414141414141414, quantile=0.5, solver=highs; total time=  20.7s
# [CV] END alpha=0.0001414141414141414, quantile=0.5, solver=highs; total time=  18.1s
# [CV] END alpha=0.0001414141414141414, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.0001414141414141414, quantile=0.5, solver=highs; total time=  18.2s
# [CV] END alpha=0.00015151515151515152, quantile=0.5, solver=highs; total time=  19.6s
# [CV] END alpha=0.00015151515151515152, quantile=0.5, solver=highs; total time=  18.4s
# [CV] END alpha=0.00015151515151515152, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.00015151515151515152, quantile=0.5, solver=highs; total time=  19.6s
# [CV] END alpha=0.00015151515151515152, quantile=0.5, solver=highs; total time=  19.6s
# [CV] END alpha=0.00016161616161616162, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=0.00016161616161616162, quantile=0.5, solver=highs; total time=  19.7s
# [CV] END alpha=0.00016161616161616162, quantile=0.5, solver=highs; total time=  19.8s
# [CV] END alpha=0.00016161616161616162, quantile=0.5, solver=highs; total time=  18.2s
# [CV] END alpha=0.00016161616161616162, quantile=0.5, solver=highs; total time=  19.9s
# [CV] END alpha=0.00017171717171717173, quantile=0.5, solver=highs; total time=  18.3s
# [CV] END alpha=0.00017171717171717173, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=0.00017171717171717173, quantile=0.5, solver=highs; total time=  20.6s
# [CV] END alpha=0.00017171717171717173, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.00017171717171717173, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=0.00018181818181818183, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.00018181818181818183, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=0.00018181818181818183, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.00018181818181818183, quantile=0.5, solver=highs; total time=  18.3s
# [CV] END alpha=0.00018181818181818183, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=0.00019191919191919191, quantile=0.5, solver=highs; total time=  19.8s
# [CV] END alpha=0.00019191919191919191, quantile=0.5, solver=highs; total time=  19.6s
# [CV] END alpha=0.00019191919191919191, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.00020202020202020202, quantile=0.5, solver=highs; total time=  18.2s
# [CV] END alpha=0.00019191919191919191, quantile=0.5, solver=highs; total time=  20.4s
# [CV] END alpha=0.00019191919191919191, quantile=0.5, solver=highs; total time=  20.2s
# [CV] END alpha=0.00020202020202020202, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.00020202020202020202, quantile=0.5, solver=highs; total time=  20.0s
# [CV] END alpha=0.00020202020202020202, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=0.00020202020202020202, quantile=0.5, solver=highs; total time=  18.5s
# [CV] END alpha=0.00021212121212121213, quantile=0.5, solver=highs; total time=  19.3s
# [CV] END alpha=0.00021212121212121213, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=0.00021212121212121213, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=0.00021212121212121213, quantile=0.5, solver=highs; total time=  19.8s
# [CV] END alpha=0.00021212121212121213, quantile=0.5, solver=highs; total time=  20.0s
# [CV] END alpha=0.00022222222222222223, quantile=0.5, solver=highs; total time=  18.6s
# [CV] END alpha=0.00022222222222222223, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.00022222222222222223, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.00022222222222222223, quantile=0.5, solver=highs; total time=  18.2s
# [CV] END alpha=0.00022222222222222223, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.00023232323232323234, quantile=0.5, solver=highs; total time=  18.6s
# [CV] END alpha=0.00023232323232323234, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.00023232323232323234, quantile=0.5, solver=highs; total time=  19.8s
# [CV] END alpha=0.00023232323232323234, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.00023232323232323234, quantile=0.5, solver=highs; total time=  19.6s
# [CV] END alpha=0.00024242424242424245, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.00024242424242424245, quantile=0.5, solver=highs; total time=  18.6s
# [CV] END alpha=0.00024242424242424245, quantile=0.5, solver=highs; total time=  19.3s
# [CV] END alpha=0.00024242424242424245, quantile=0.5, solver=highs; total time=  19.5s
# [CV] END alpha=0.0002525252525252525, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.00024242424242424245, quantile=0.5, solver=highs; total time=  19.3s
# [CV] END alpha=0.0002525252525252525, quantile=0.5, solver=highs; total time=  19.4s
# [CV] END alpha=0.0002525252525252525, quantile=0.5, solver=highs; total time=  20.3s
# [CV] END alpha=0.0002525252525252525, quantile=0.5, solver=highs; total time=  18.5s
# [CV] END alpha=0.0002525252525252525, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=0.00026262626262626266, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.00026262626262626266, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=0.00026262626262626266, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=0.00026262626262626266, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=0.00026262626262626266, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=0.00027272727272727274, quantile=0.5, solver=highs; total time=  19.5s
# [CV] END alpha=0.00027272727272727274, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.00027272727272727274, quantile=0.5, solver=highs; total time=  18.7s
# [CV] END alpha=0.00027272727272727274, quantile=0.5, solver=highs; total time=  18.3s
# [CV] END alpha=0.00027272727272727274, quantile=0.5, solver=highs; total time=  18.6s
# [CV] END alpha=0.0002828282828282828, quantile=0.5, solver=highs; total time=  19.4s
# [CV] END alpha=0.0002828282828282828, quantile=0.5, solver=highs; total time=  19.7s
# [CV] END alpha=0.0002828282828282828, quantile=0.5, solver=highs; total time=  19.5s
# [CV] END alpha=0.0002828282828282828, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.0002828282828282828, quantile=0.5, solver=highs; total time=  17.8s
# [CV] END alpha=0.00029292929292929295, quantile=0.5, solver=highs; total time=  18.6s
# [CV] END alpha=0.00029292929292929295, quantile=0.5, solver=highs; total time=  19.4s
# [CV] END alpha=0.00029292929292929295, quantile=0.5, solver=highs; total time=  19.5s
# [CV] END alpha=0.00029292929292929295, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=0.00030303030303030303, quantile=0.5, solver=highs; total time=  19.7s
# [CV] END alpha=0.00029292929292929295, quantile=0.5, solver=highs; total time=  20.0s
# [CV] END alpha=0.00030303030303030303, quantile=0.5, solver=highs; total time=  20.8s
# [CV] END alpha=0.00030303030303030303, quantile=0.5, solver=highs; total time=  18.0s
# [CV] END alpha=0.00030303030303030303, quantile=0.5, solver=highs; total time=  19.3s
# [CV] END alpha=0.00030303030303030303, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=0.00031313131313131316, quantile=0.5, solver=highs; total time=  18.7s
# [CV] END alpha=0.00031313131313131316, quantile=0.5, solver=highs; total time=  17.7s
# [CV] END alpha=0.00031313131313131316, quantile=0.5, solver=highs; total time=  17.8s
# [CV] END alpha=0.00031313131313131316, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.00031313131313131316, quantile=0.5, solver=highs; total time=  20.6s
# [CV] END alpha=0.00032323232323232324, quantile=0.5, solver=highs; total time=  19.3s
# [CV] END alpha=0.00032323232323232324, quantile=0.5, solver=highs; total time=  19.5s
# [CV] END alpha=0.00032323232323232324, quantile=0.5, solver=highs; total time=  17.5s
# [CV] END alpha=0.00032323232323232324, quantile=0.5, solver=highs; total time=  19.6s
# [CV] END alpha=0.00032323232323232324, quantile=0.5, solver=highs; total time=  19.3s
# [CV] END alpha=0.0003333333333333333, quantile=0.5, solver=highs; total time=  19.3s
# [CV] END alpha=0.0003333333333333333, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.0003333333333333333, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=0.0003333333333333333, quantile=0.5, solver=highs; total time=  18.4s
# [CV] END alpha=0.00034343434343434346, quantile=0.5, solver=highs; total time=  17.9s
# [CV] END alpha=0.0003333333333333333, quantile=0.5, solver=highs; total time=  18.3s
# [CV] END alpha=0.00034343434343434346, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.00034343434343434346, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.00034343434343434346, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=0.00034343434343434346, quantile=0.5, solver=highs; total time=  19.5s
# [CV] END alpha=0.00035353535353535354, quantile=0.5, solver=highs; total time=  18.3s
# [CV] END alpha=0.00035353535353535354, quantile=0.5, solver=highs; total time=  18.5s
# [CV] END alpha=0.00035353535353535354, quantile=0.5, solver=highs; total time=  18.7s
# [CV] END alpha=0.00035353535353535354, quantile=0.5, solver=highs; total time=  21.5s
# [CV] END alpha=0.00035353535353535354, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.00036363636363636367, quantile=0.5, solver=highs; total time=  20.3s
# [CV] END alpha=0.00036363636363636367, quantile=0.5, solver=highs; total time=  18.6s
# [CV] END alpha=0.00036363636363636367, quantile=0.5, solver=highs; total time=  20.2s
# [CV] END alpha=0.00037373737373737375, quantile=0.5, solver=highs; total time=  18.2s
# [CV] END alpha=0.00036363636363636367, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.00036363636363636367, quantile=0.5, solver=highs; total time=  18.7s
# [CV] END alpha=0.00037373737373737375, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.00037373737373737375, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.00037373737373737375, quantile=0.5, solver=highs; total time=  17.8s
# [CV] END alpha=0.00037373737373737375, quantile=0.5, solver=highs; total time=  19.6s
# [CV] END alpha=0.00038383838383838383, quantile=0.5, solver=highs; total time=  19.3s
# [CV] END alpha=0.00038383838383838383, quantile=0.5, solver=highs; total time=  17.8s
# [CV] END alpha=0.00038383838383838383, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.00038383838383838383, quantile=0.5, solver=highs; total time=  19.5s
# [CV] END alpha=0.00038383838383838383, quantile=0.5, solver=highs; total time=  19.7s
# [CV] END alpha=0.00039393939393939396, quantile=0.5, solver=highs; total time=  20.7s
# [CV] END alpha=0.00039393939393939396, quantile=0.5, solver=highs; total time=  18.0s
# [CV] END alpha=0.00039393939393939396, quantile=0.5, solver=highs; total time=  20.0s
# [CV] END alpha=0.00039393939393939396, quantile=0.5, solver=highs; total time=  20.0s
# [CV] END alpha=0.00039393939393939396, quantile=0.5, solver=highs; total time=  19.9s
# [CV] END alpha=0.00040404040404040404, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.00040404040404040404, quantile=0.5, solver=highs; total time=  20.3s
# [CV] END alpha=0.00040404040404040404, quantile=0.5, solver=highs; total time=  21.2s
# [CV] END alpha=0.00040404040404040404, quantile=0.5, solver=highs; total time=  19.6s
# [CV] END alpha=0.00040404040404040404, quantile=0.5, solver=highs; total time=  20.3s
# [CV] END alpha=0.0004141414141414142, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=0.0004141414141414142, quantile=0.5, solver=highs; total time=  19.6s
# [CV] END alpha=0.0004141414141414142, quantile=0.5, solver=highs; total time=  18.5s
# [CV] END alpha=0.0004141414141414142, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=0.0004141414141414142, quantile=0.5, solver=highs; total time=  18.4s
# [CV] END alpha=0.00042424242424242425, quantile=0.5, solver=highs; total time=  18.5s
# [CV] END alpha=0.00042424242424242425, quantile=0.5, solver=highs; total time=  18.7s
# [CV] END alpha=0.00042424242424242425, quantile=0.5, solver=highs; total time=  20.2s
# [CV] END alpha=0.00042424242424242425, quantile=0.5, solver=highs; total time=  18.7s
# [CV] END alpha=0.00042424242424242425, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.00043434343434343433, quantile=0.5, solver=highs; total time=  18.1s
# [CV] END alpha=0.00043434343434343433, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.00043434343434343433, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=0.00043434343434343433, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.00043434343434343433, quantile=0.5, solver=highs; total time=  19.3s
# [CV] END alpha=0.00044444444444444447, quantile=0.5, solver=highs; total time=  19.7s
# [CV] END alpha=0.00044444444444444447, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=0.00044444444444444447, quantile=0.5, solver=highs; total time=  20.0s
# [CV] END alpha=0.00044444444444444447, quantile=0.5, solver=highs; total time=  17.8s
# [CV] END alpha=0.00044444444444444447, quantile=0.5, solver=highs; total time=  18.3s
# [CV] END alpha=0.00045454545454545455, quantile=0.5, solver=highs; total time=  17.9s
# [CV] END alpha=0.00045454545454545455, quantile=0.5, solver=highs; total time=  17.9s
# [CV] END alpha=0.00045454545454545455, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.00045454545454545455, quantile=0.5, solver=highs; total time=  19.4s
# [CV] END alpha=0.00045454545454545455, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.0004646464646464647, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.0004646464646464647, quantile=0.5, solver=highs; total time=  20.0s
# [CV] END alpha=0.0004646464646464647, quantile=0.5, solver=highs; total time=  18.7s
# [CV] END alpha=0.0004646464646464647, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.0004646464646464647, quantile=0.5, solver=highs; total time=  18.1s
# [CV] END alpha=0.00047474747474747476, quantile=0.5, solver=highs; total time=  19.5s
# [CV] END alpha=0.00047474747474747476, quantile=0.5, solver=highs; total time=  18.6s
# [CV] END alpha=0.00047474747474747476, quantile=0.5, solver=highs; total time=  21.5s
# [CV] END alpha=0.00047474747474747476, quantile=0.5, solver=highs; total time=  19.3s
# [CV] END alpha=0.0004848484848484849, quantile=0.5, solver=highs; total time=  18.2s
# [CV] END alpha=0.00047474747474747476, quantile=0.5, solver=highs; total time=  18.4s
# [CV] END alpha=0.0004848484848484849, quantile=0.5, solver=highs; total time=  18.3s
# [CV] END alpha=0.0004848484848484849, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.0004848484848484849, quantile=0.5, solver=highs; total time=  18.3s
# [CV] END alpha=0.0004848484848484849, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.000494949494949495, quantile=0.5, solver=highs; total time=  20.4s
# [CV] END alpha=0.000494949494949495, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.000494949494949495, quantile=0.5, solver=highs; total time=  18.6s
# [CV] END alpha=0.000494949494949495, quantile=0.5, solver=highs; total time=  19.6s
# [CV] END alpha=0.000494949494949495, quantile=0.5, solver=highs; total time=  19.6s
# [CV] END alpha=0.000505050505050505, quantile=0.5, solver=highs; total time=  17.7s
# [CV] END alpha=0.000505050505050505, quantile=0.5, solver=highs; total time=  19.6s
# [CV] END alpha=0.000505050505050505, quantile=0.5, solver=highs; total time=  19.3s
# [CV] END alpha=0.000505050505050505, quantile=0.5, solver=highs; total time=  19.4s
# [CV] END alpha=0.000505050505050505, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=0.0005151515151515151, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=0.0005151515151515151, quantile=0.5, solver=highs; total time=  18.0s
# [CV] END alpha=0.0005151515151515151, quantile=0.5, solver=highs; total time=  17.6s
# [CV] END alpha=0.0005151515151515151, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.0005151515151515151, quantile=0.5, solver=highs; total time=  18.7s
# [CV] END alpha=0.0005252525252525253, quantile=0.5, solver=highs; total time=  19.5s
# [CV] END alpha=0.0005252525252525253, quantile=0.5, solver=highs; total time=  20.6s
# [CV] END alpha=0.0005252525252525253, quantile=0.5, solver=highs; total time=  19.6s
# [CV] END alpha=0.0005252525252525253, quantile=0.5, solver=highs; total time=  18.3s
# [CV] END alpha=0.0005252525252525253, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=0.0005353535353535354, quantile=0.5, solver=highs; total time=  18.4s
# [CV] END alpha=0.0005353535353535354, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.0005353535353535354, quantile=0.5, solver=highs; total time=  19.3s
# [CV] END alpha=0.0005353535353535354, quantile=0.5, solver=highs; total time=  18.3s
# [CV] END alpha=0.0005353535353535354, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.0005454545454545455, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=0.0005454545454545455, quantile=0.5, solver=highs; total time=  17.9s
# [CV] END alpha=0.0005454545454545455, quantile=0.5, solver=highs; total time=  18.1s
# [CV] END alpha=0.0005454545454545455, quantile=0.5, solver=highs; total time=  17.7s
# [CV] END alpha=0.0005454545454545455, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.0005555555555555556, quantile=0.5, solver=highs; total time=  20.0s
# [CV] END alpha=0.0005555555555555556, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=0.0005555555555555556, quantile=0.5, solver=highs; total time=  18.0s
# [CV] END alpha=0.0005555555555555556, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=0.0005555555555555556, quantile=0.5, solver=highs; total time=  19.8s
# [CV] END alpha=0.0005656565656565656, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.0005656565656565656, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.0005656565656565656, quantile=0.5, solver=highs; total time=  18.7s
# [CV] END alpha=0.0005656565656565656, quantile=0.5, solver=highs; total time=  18.3s
# [CV] END alpha=0.0005656565656565656, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=0.0005757575757575758, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.0005757575757575758, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.0005757575757575758, quantile=0.5, solver=highs; total time=  19.5s
# [CV] END alpha=0.0005757575757575758, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.0005757575757575758, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=0.0005858585858585859, quantile=0.5, solver=highs; total time=  18.3s
# [CV] END alpha=0.0005858585858585859, quantile=0.5, solver=highs; total time=  17.6s
# [CV] END alpha=0.0005858585858585859, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.0005858585858585859, quantile=0.5, solver=highs; total time=  19.6s
# [CV] END alpha=0.000595959595959596, quantile=0.5, solver=highs; total time=  18.1s
# [CV] END alpha=0.0005858585858585859, quantile=0.5, solver=highs; total time=  20.0s
# [CV] END alpha=0.000595959595959596, quantile=0.5, solver=highs; total time=  19.8s
# [CV] END alpha=0.000595959595959596, quantile=0.5, solver=highs; total time=  19.6s
# [CV] END alpha=0.000595959595959596, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.000595959595959596, quantile=0.5, solver=highs; total time=  18.5s
# [CV] END alpha=0.0006060606060606061, quantile=0.5, solver=highs; total time=  18.5s
# [CV] END alpha=0.0006060606060606061, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.0006161616161616161, quantile=0.5, solver=highs; total time=  17.7s
# [CV] END alpha=0.0006060606060606061, quantile=0.5, solver=highs; total time=  19.3s
# [CV] END alpha=0.0006060606060606061, quantile=0.5, solver=highs; total time=  19.4s
# [CV] END alpha=0.0006060606060606061, quantile=0.5, solver=highs; total time=  20.2s
# [CV] END alpha=0.0006161616161616161, quantile=0.5, solver=highs; total time=  17.4s
# [CV] END alpha=0.0006161616161616161, quantile=0.5, solver=highs; total time=  20.5s
# [CV] END alpha=0.0006161616161616161, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=0.0006262626262626263, quantile=0.5, solver=highs; total time=  17.8s
# [CV] END alpha=0.0006161616161616161, quantile=0.5, solver=highs; total time=  18.6s
# [CV] END alpha=0.0006262626262626263, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.0006262626262626263, quantile=0.5, solver=highs; total time=  18.7s
# [CV] END alpha=0.0006262626262626263, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.0006262626262626263, quantile=0.5, solver=highs; total time=  17.7s
# [CV] END alpha=0.0006363636363636364, quantile=0.5, solver=highs; total time=  18.2s
# [CV] END alpha=0.0006363636363636364, quantile=0.5, solver=highs; total time=  18.4s
# [CV] END alpha=0.0006363636363636364, quantile=0.5, solver=highs; total time=  18.1s
# [CV] END alpha=0.0006363636363636364, quantile=0.5, solver=highs; total time=  20.2s
# [CV] END alpha=0.0006464646464646465, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.0006363636363636364, quantile=0.5, solver=highs; total time=  19.6s
# [CV] END alpha=0.0006464646464646465, quantile=0.5, solver=highs; total time=  19.3s
# [CV] END alpha=0.0006464646464646465, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.0006464646464646465, quantile=0.5, solver=highs; total time=  19.5s
# [CV] END alpha=0.0006464646464646465, quantile=0.5, solver=highs; total time=  18.6s
# [CV] END alpha=0.0006565656565656566, quantile=0.5, solver=highs; total time=  18.5s
# [CV] END alpha=0.0006565656565656566, quantile=0.5, solver=highs; total time=  17.4s
# [CV] END alpha=0.0006565656565656566, quantile=0.5, solver=highs; total time=  18.0s
# [CV] END alpha=0.0006565656565656566, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.0006565656565656566, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.0006666666666666666, quantile=0.5, solver=highs; total time=  18.4s
# [CV] END alpha=0.0006666666666666666, quantile=0.5, solver=highs; total time=  19.5s
# [CV] END alpha=0.0006666666666666666, quantile=0.5, solver=highs; total time=  19.4s
# [CV] END alpha=0.0006666666666666666, quantile=0.5, solver=highs; total time=  17.7s
# [CV] END alpha=0.0006666666666666666, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.0006767676767676768, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.0006767676767676768, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.0006767676767676768, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.0006767676767676768, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.0006767676767676768, quantile=0.5, solver=highs; total time=  18.4s
# [CV] END alpha=0.0006868686868686869, quantile=0.5, solver=highs; total time=  18.4s
# [CV] END alpha=0.0006868686868686869, quantile=0.5, solver=highs; total time=  17.9s
# [CV] END alpha=0.0006868686868686869, quantile=0.5, solver=highs; total time=  17.5s
# [CV] END alpha=0.0006868686868686869, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.0006868686868686869, quantile=0.5, solver=highs; total time=  18.6s
# [CV] END alpha=0.000696969696969697, quantile=0.5, solver=highs; total time=  19.9s
# [CV] END alpha=0.000696969696969697, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.000696969696969697, quantile=0.5, solver=highs; total time=  18.6s
# [CV] END alpha=0.000696969696969697, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.000696969696969697, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.0007070707070707071, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=0.0007070707070707071, quantile=0.5, solver=highs; total time=  19.3s
# [CV] END alpha=0.0007070707070707071, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.0007070707070707071, quantile=0.5, solver=highs; total time=  19.7s
# [CV] END alpha=0.0007070707070707071, quantile=0.5, solver=highs; total time=  18.6s
# [CV] END alpha=0.0007171717171717171, quantile=0.5, solver=highs; total time=  17.6s
# [CV] END alpha=0.0007171717171717171, quantile=0.5, solver=highs; total time=  18.4s
# [CV] END alpha=0.0007171717171717171, quantile=0.5, solver=highs; total time=  18.2s
# [CV] END alpha=0.0007171717171717171, quantile=0.5, solver=highs; total time=  18.4s
# [CV] END alpha=0.0007171717171717171, quantile=0.5, solver=highs; total time=  18.4s
# [CV] END alpha=0.0007272727272727273, quantile=0.5, solver=highs; total time=  19.4s
# [CV] END alpha=0.0007272727272727273, quantile=0.5, solver=highs; total time=  18.6s
# [CV] END alpha=0.0007272727272727273, quantile=0.5, solver=highs; total time=  19.8s
# [CV] END alpha=0.0007272727272727273, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=0.0007272727272727273, quantile=0.5, solver=highs; total time=  18.6s
# [CV] END alpha=0.0007373737373737374, quantile=0.5, solver=highs; total time=  18.3s
# [CV] END alpha=0.0007373737373737374, quantile=0.5, solver=highs; total time=  18.3s
# [CV] END alpha=0.0007373737373737374, quantile=0.5, solver=highs; total time=  18.0s
# [CV] END alpha=0.0007373737373737374, quantile=0.5, solver=highs; total time=  17.9s
# [CV] END alpha=0.0007373737373737374, quantile=0.5, solver=highs; total time=  18.4s
# [CV] END alpha=0.0007474747474747475, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.0007474747474747475, quantile=0.5, solver=highs; total time=  17.9s
# [CV] END alpha=0.0007474747474747475, quantile=0.5, solver=highs; total time=  18.4s
# [CV] END alpha=0.0007474747474747475, quantile=0.5, solver=highs; total time=  17.7s
# [CV] END alpha=0.0007474747474747475, quantile=0.5, solver=highs; total time=  20.1s
# [CV] END alpha=0.0007575757575757576, quantile=0.5, solver=highs; total time=  17.4s
# [CV] END alpha=0.0007575757575757576, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.0007575757575757576, quantile=0.5, solver=highs; total time=  19.4s
# [CV] END alpha=0.0007575757575757576, quantile=0.5, solver=highs; total time=  19.3s
# [CV] END alpha=0.0007575757575757576, quantile=0.5, solver=highs; total time=  19.5s
# [CV] END alpha=0.0007676767676767677, quantile=0.5, solver=highs; total time=  19.8s
# [CV] END alpha=0.0007676767676767677, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=0.0007676767676767677, quantile=0.5, solver=highs; total time=  18.2s
# [CV] END alpha=0.0007676767676767677, quantile=0.5, solver=highs; total time=  17.9s
# [CV] END alpha=0.0007676767676767677, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=0.0007777777777777778, quantile=0.5, solver=highs; total time=  17.8s
# [CV] END alpha=0.0007777777777777778, quantile=0.5, solver=highs; total time=  18.1s
# [CV] END alpha=0.0007777777777777778, quantile=0.5, solver=highs; total time=  19.4s
# [CV] END alpha=0.0007777777777777778, quantile=0.5, solver=highs; total time=  17.4s
# [CV] END alpha=0.0007777777777777778, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=0.0007878787878787879, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.0007878787878787879, quantile=0.5, solver=highs; total time=  19.4s
# [CV] END alpha=0.0007878787878787879, quantile=0.5, solver=highs; total time=  19.8s
# [CV] END alpha=0.0007878787878787879, quantile=0.5, solver=highs; total time=  17.1s
# [CV] END alpha=0.0007878787878787879, quantile=0.5, solver=highs; total time=  18.6s
# [CV] END alpha=0.000797979797979798, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.000797979797979798, quantile=0.5, solver=highs; total time=  18.1s
# [CV] END alpha=0.000797979797979798, quantile=0.5, solver=highs; total time=  17.9s
# [CV] END alpha=0.000797979797979798, quantile=0.5, solver=highs; total time=  17.9s
# [CV] END alpha=0.000797979797979798, quantile=0.5, solver=highs; total time=  18.2s
# [CV] END alpha=0.0008080808080808081, quantile=0.5, solver=highs; total time=  17.9s
# [CV] END alpha=0.0008080808080808081, quantile=0.5, solver=highs; total time=  17.6s
# [CV] END alpha=0.0008080808080808081, quantile=0.5, solver=highs; total time=  18.3s
# [CV] END alpha=0.0008080808080808081, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.0008080808080808081, quantile=0.5, solver=highs; total time=  20.1s
# [CV] END alpha=0.0008181818181818182, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.0008181818181818182, quantile=0.5, solver=highs; total time=  18.7s
# [CV] END alpha=0.0008181818181818182, quantile=0.5, solver=highs; total time=  18.5s
# [CV] END alpha=0.0008181818181818182, quantile=0.5, solver=highs; total time=  19.3s
# [CV] END alpha=0.0008181818181818182, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=0.0008282828282828283, quantile=0.5, solver=highs; total time=  19.8s
# [CV] END alpha=0.0008282828282828283, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=0.0008282828282828283, quantile=0.5, solver=highs; total time=  17.2s
# [CV] END alpha=0.0008282828282828283, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=0.0008282828282828283, quantile=0.5, solver=highs; total time=  18.3s
# [CV] END alpha=0.0008383838383838384, quantile=0.5, solver=highs; total time=  17.5s
# [CV] END alpha=0.0008383838383838384, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.0008383838383838384, quantile=0.5, solver=highs; total time=  18.7s
# [CV] END alpha=0.0008383838383838384, quantile=0.5, solver=highs; total time=  18.3s
# [CV] END alpha=0.0008383838383838384, quantile=0.5, solver=highs; total time=  20.2s
# [CV] END alpha=0.0008484848484848485, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=0.0008484848484848485, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.0008484848484848485, quantile=0.5, solver=highs; total time=  17.7s
# [CV] END alpha=0.0008484848484848485, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.0008585858585858586, quantile=0.5, solver=highs; total time=  18.7s
# [CV] END alpha=0.0008484848484848485, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.0008585858585858586, quantile=0.5, solver=highs; total time=  18.2s
# [CV] END alpha=0.0008585858585858586, quantile=0.5, solver=highs; total time=  17.6s
# [CV] END alpha=0.0008585858585858586, quantile=0.5, solver=highs; total time=  18.1s
# [CV] END alpha=0.0008585858585858586, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.0008686868686868687, quantile=0.5, solver=highs; total time=  18.2s
# [CV] END alpha=0.0008686868686868687, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.0008686868686868687, quantile=0.5, solver=highs; total time=  17.3s
# [CV] END alpha=0.0008686868686868687, quantile=0.5, solver=highs; total time=  20.6s
# [CV] END alpha=0.0008686868686868687, quantile=0.5, solver=highs; total time=  19.3s
# [CV] END alpha=0.0008787878787878789, quantile=0.5, solver=highs; total time=  18.7s
# [CV] END alpha=0.0008787878787878789, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.0008787878787878789, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=0.0008787878787878789, quantile=0.5, solver=highs; total time=  19.5s
# [CV] END alpha=0.0008787878787878789, quantile=0.5, solver=highs; total time=  18.4s
# [CV] END alpha=0.0008888888888888889, quantile=0.5, solver=highs; total time=  17.9s
# [CV] END alpha=0.0008888888888888889, quantile=0.5, solver=highs; total time=  18.7s
# [CV] END alpha=0.0008888888888888889, quantile=0.5, solver=highs; total time=  18.1s
# [CV] END alpha=0.0008888888888888889, quantile=0.5, solver=highs; total time=  17.4s
# [CV] END alpha=0.0008888888888888889, quantile=0.5, solver=highs; total time=  18.1s
# [CV] END alpha=0.000898989898989899, quantile=0.5, solver=highs; total time=  19.3s
# [CV] END alpha=0.000898989898989899, quantile=0.5, solver=highs; total time=  18.2s
# [CV] END alpha=0.000898989898989899, quantile=0.5, solver=highs; total time=  17.5s
# [CV] END alpha=0.000898989898989899, quantile=0.5, solver=highs; total time=  19.5s
# [CV] END alpha=0.000898989898989899, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.0009090909090909091, quantile=0.5, solver=highs; total time=  18.1s
# [CV] END alpha=0.0009090909090909091, quantile=0.5, solver=highs; total time=  19.4s
# [CV] END alpha=0.0009090909090909091, quantile=0.5, solver=highs; total time=  18.7s
# [CV] END alpha=0.0009090909090909091, quantile=0.5, solver=highs; total time=  19.5s
# [CV] END alpha=0.0009090909090909091, quantile=0.5, solver=highs; total time=  18.4s
# [CV] END alpha=0.0009191919191919192, quantile=0.5, solver=highs; total time=  18.4s
# [CV] END alpha=0.0009191919191919192, quantile=0.5, solver=highs; total time=  17.8s
# [CV] END alpha=0.0009191919191919192, quantile=0.5, solver=highs; total time=  19.1s
# [CV] END alpha=0.0009191919191919192, quantile=0.5, solver=highs; total time=  18.3s
# [CV] END alpha=0.0009292929292929294, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.0009191919191919192, quantile=0.5, solver=highs; total time=  19.4s
# [CV] END alpha=0.0009292929292929294, quantile=0.5, solver=highs; total time=  19.4s
# [CV] END alpha=0.0009292929292929294, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.0009292929292929294, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.0009292929292929294, quantile=0.5, solver=highs; total time=  18.6s
# [CV] END alpha=0.0009393939393939394, quantile=0.5, solver=highs; total time=  19.2s
# [CV] END alpha=0.0009393939393939394, quantile=0.5, solver=highs; total time=  18.8s
# [CV] END alpha=0.0009393939393939394, quantile=0.5, solver=highs; total time=  17.6s
# [CV] END alpha=0.0009393939393939394, quantile=0.5, solver=highs; total time=  19.4s
# [CV] END alpha=0.0009494949494949495, quantile=0.5, solver=highs; total time=  18.5s
# [CV] END alpha=0.0009393939393939394, quantile=0.5, solver=highs; total time=  19.6s
# [CV] END alpha=0.0009494949494949495, quantile=0.5, solver=highs; total time=  17.6s
# [CV] END alpha=0.0009494949494949495, quantile=0.5, solver=highs; total time=  18.1s
# [CV] END alpha=0.0009494949494949495, quantile=0.5, solver=highs; total time=  18.1s
# [CV] END alpha=0.0009494949494949495, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=0.0009595959595959596, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=0.0009595959595959596, quantile=0.5, solver=highs; total time=  17.5s
# [CV] END alpha=0.0009595959595959596, quantile=0.5, solver=highs; total time=  18.6s
# [CV] END alpha=0.0009595959595959596, quantile=0.5, solver=highs; total time=  18.7s
# [CV] END alpha=0.0009595959595959596, quantile=0.5, solver=highs; total time=  19.0s
# [CV] END alpha=0.0009696969696969698, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=0.0009696969696969698, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END alpha=0.0009696969696969698, quantile=0.5, solver=highs; total time=  18.7s
# [CV] END alpha=0.0009696969696969698, quantile=0.5, solver=highs; total time=  17.4s
# [CV] END alpha=0.0009696969696969698, quantile=0.5, solver=highs; total time=  18.2s
# [CV] END alpha=0.0009797979797979799, quantile=0.5, solver=highs; total time=  18.1s
# [CV] END alpha=0.0009797979797979799, quantile=0.5, solver=highs; total time=  20.1s
# [CV] END alpha=0.0009797979797979799, quantile=0.5, solver=highs; total time=  18.7s
# [CV] END alpha=0.0009797979797979799, quantile=0.5, solver=highs; total time=  17.7s
# [CV] END alpha=0.0009797979797979799, quantile=0.5, solver=highs; total time=  18.7s
# [CV] END alpha=0.00098989898989899, quantile=0.5, solver=highs; total time=  18.4s
# [CV] END alpha=0.00098989898989899, quantile=0.5, solver=highs; total time=  18.0s
# [CV] END alpha=0.00098989898989899, quantile=0.5, solver=highs; total time=  18.3s
# [CV] END alpha=0.00098989898989899, quantile=0.5, solver=highs; total time=  17.5s
# [CV] END ............alpha=0.001, quantile=0.5, solver=highs; total time=  16.2s
# [CV] END alpha=0.00098989898989899, quantile=0.5, solver=highs; total time=  18.9s
# [CV] END ............alpha=0.001, quantile=0.5, solver=highs; total time=  17.6s
# [CV] END ............alpha=0.001, quantile=0.5, solver=highs; total time=  12.0s
# [CV] END ............alpha=0.001, quantile=0.5, solver=highs; total time=  12.5s
# [CV] END ............alpha=0.001, quantile=0.5, solver=highs; total time=   9.8s
# fitting time: 1175.5046994686127
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 15
#      13 clf = grid_search(QuantileRegressor(), X_train, y_train)
#      14 best_after_grid = clf.best_estimator_
# ---> 15 mean_absolute_error()
#      16 y_pred_train = clf.predict(X_train)
#      17 y_pred_test = clf.predict(X_test)
#
# File ~/podstawy-uczenia-maszynowego-24-25/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:194, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     191 func_sig = signature(func)
#     193 # Map *args/**kwargs to the function signature
# --> 194 params = func_sig.bind(*args, **kwargs)
#     195 params.apply_defaults()
#     197 # ignore self/cls and positional/keyword markers
#
# File ~/.local/share/uv/python/cpython-3.11.11-linux-x86_64-gnu/lib/python3.11/inspect.py:3195, in Signature.bind(self, *args, **kwargs)
#    3190 def bind(self, /, *args, **kwargs):
#    3191     """Get a BoundArguments object, that maps the passed `args`
#    3192     and `kwargs` to the function's signature.  Raises `TypeError`
#    3193     if the passed arguments can not be bound.
#    3194     """
# -> 3195     return self._bind(args, kwargs)
#
# File ~/.local/share/uv/python/cpython-3.11.11-linux-x86_64-gnu/lib/python3.11/inspect.py:3110, in Signature._bind(self, args, kwargs, partial)
#    3108                 msg = 'missing a required argument: {arg!r}'
#    3109                 msg = msg.format(arg=param.name)
# -> 3110                 raise TypeError(msg) from None
#    3111 else:
#    3112     # We have a positional argument to process
#    3113     try:
#
# TypeError: missing a required argument: 'y_true'

# %%
y_pred_train = clf.predict(X_train)
y_pred_test = clf.predict(X_test)
evaluate_model(y_train, y_test, y_pred_train, y_pred_test)
# Out:
# Train RMSE 18170.97, MAE: 11649.58
# Test  RMSE 18189.07, MAE: 12371.05

# %% [markdown]
# Wyniki względem czasu nie są powalające chyba nie warte czasu

# %% [markdown]
# Zamiast używać regresji LAD, opartej o programowanie liniowe, można też wykorzystać Huber regression. Jest ono mało czuła zarówno na $\epsilon$ (punkt przejścia z MSE do MAE), jak i $\alpha$ (siłę regularyzacji L2), więc często nie wymaga tuningu hiperparametrów.
#
# **Zadanie 9 (0.5 punktu)**
#
# Wytrenuj model Huber regression. Sprawdź jakość modelu. Skomentuj różnicę czasową i jakościową względem LAD regression (tutaj oczywiście bez tuningu). Z którego modelu skorzystałbyś w praktyce?
#
# Domyślna liczba iteracji solwera, 100, jest zbyt mała dla naszej liczby cech, i będą z tego wynikać ostrzeżenia o braku zbieżności, więc zwiększ ją do 2000.

# %%
from sklearn.linear_model import HuberRegressor
huber_reg = HuberRegressor(max_iter=2000)
t = time()
huber_reg.fit(X_train, y_train)
print('huber time:', time()-t)
y_pred_train = huber_reg.predict(X_train)
y_pred_test = huber_reg.predict(X_test)
evaluate_model(y_train, y_test, y_pred_train, y_pred_test)
# Out:
# huber time: 1.606945276260376
# Train RMSE 18576.99, MAE: 11700.91
# Test  RMSE 17988.02, MAE: 12247.75

# %% [markdown]
# `Huber` ma najlepszy balans między jakością a czasem trenowania

# %% [markdown]
# ## Use case, połączenie w system end-to-end

# %% [markdown]
# Na rynku działa firma oferująca serwis do sprzedaży nieruchomości. CEO był na prezentacji o AI, zaczął używać ChatGPT i uznał, że też musicie mieć taki potężny ML. Zostałeś zatrudniony jako (pierwszy i jedyny) data scientist, zebrałeś historyczne dane, i nawet wdrożyłeś pierwszy model regresji liniowej do estymacji wartości nieruchomości.
#
# Pewnego dnia Product Owner przychodzi do ciebie z listą "absolutnie krytycznych" wymagań (propozycja nie do odrzucenia):
# 1. Ciągle coś się sypie na produkcji, bo obecny pipeline do przetwarzania cech jest złożony z wielu kroków, które są copy-paste z twojego Jupyter Notebooka. Trzeba z tego zrobić jeden obiekt, zapisywać i wdrażać end-to-end.
# 2. Nowe domy czasem mają ekstremalne wartości cech, których nie było w zbiorze treningowym, i na tych przypadkach model radzi sobie wystarczająco słabo. Może wystarczyłoby je jakoś przyciąć?
# 3. Obecny model regresji liniowej działa w miarę ok, ale trzeba czegoś lepszego, co dawałoby lepsze MAE, bo większość klientów jest zainteresowana przeciętnie drogimi nieruchomościami.
# 4. Sama przewidywana wartość nieruchomości to za mało, bo każdy wie, że ceny są zróżnicowane. Twoja regresja liniowa podaje tylko warunkową średnią, a zarówno sprzedający, jak i kupujący chcieliby znać sensowne górne i dolne widełki. Product Owner ze swojego doświadczenia sugeruje, że typowo takie wahania różnią się co najwyżej o 15 punktów procentowych w górę i dół od średniej ceny.
#
# **Zadanie 10 (4 punkty)**
#
# 1. Połącz wszystkie wcześniejsze transformery dla zmiennych numerycznych i kategorycznych w jeden duży `ColumnTransformer`. Ma do niego wejść cale `X_train_raw`, a wyjść gotowy output.
# 2. Przycinanie wartości do zakresu znanego ze zbioru treningowego nazywa się czasem **winsoryzacją (winsorization)**. Dodaj taki etap po skalowaniu min-max, a przed selekcją według korelacji. Przydatny będzie tutaj Feature-engine.
# 3. Na podstawie wcześniejszych eksperymentów wybierz model do przewidywania własności domów. Wybór uzasadnij w komentarzu. W razie potrzeby dokonaj tuningu hiperparametrów. Zmierz jakość modelu.
# 4. Wybierz i wytrenuj odpowiednie modele do regresji, żeby dostać estymację 35% i 65% ceny, w dodatku do przeciętnej ceny (estymowanej przez model z poprzedniego punktu). Dokonaj w razie potrzeby tuningu hiperparametrów. Metryką jakości może być tutaj [D^2 pinball score](d2_pinball_score), który ma wygodny zakres wartości $[0, 1]$ (dla dobrych modeli, im bliżej 1, tym lepiej). Podaj jakość finalnych modeli.
# 5. Zapisz transformer do preprocessingu oraz estymatory do regresji do plików [z pomocą Jobliba](https://scikit-learn.org/stable/model_persistence.html): `ames_transformer.joblib`, `price_estimator.joblib`, `low_price_estimator.joblib`, `high_price_estimator.joblib`.
#
# Poniżej przygotowano funkcję testową, która ładuje transformer i estymatory, oraz oblicza predykcje dla trzech przykładowych domów ze zbioru testowego (taniego, przeciętnego i drogiego).
#
# Skomentuj - czy twoim zdaniem finalne modele, podające przeciętną wartość i widełki, są subiektywnie dobrej jakości?

# %%
from feature_engine.outliers import Winsorizer
import joblib

capper = Winsorizer(capping_method='gaussian',
                    tail = "right",
                    fold=3)

num_overall_pipeline = Pipeline([
        ("input", inputer), 
        ("scaling", scaler),
        ("winsorization", capper),
        ("selection", selector)
    ])

category_pipeline = Pipeline([
        ("rare", RareLabelEncoder(tol=0.01, n_categories=0, replace_with="Rare")),
        ("onehot", OneHotEncoder(drop="first", sparse_output=False, handle_unknown="ignore"))
    ])

overall_transformer = ColumnTransformer([
        ("numerical transform", num_overall_pipeline, numerical_features),
        ("category transform", category_pipeline, categorical_features)
    ], verbose_feature_names_out=False)


X_train_overall = overall_transformer.fit_transform(X_train_raw, y_train)
X_test_overall = overall_transformer.transform(X_test_raw)

joblib.dump(overall_transformer, "ames_transformer.joblib")
# Out:
# ['ames_transformer.joblib']

# %%
huber_true_price = HuberRegressor(max_iter=2000)
huber_true_price.fit(X_train_overall, y_train)


huber_low_price = HuberRegressor(max_iter=2000)
huber_low_price.fit(X_train_overall, np.log1p( np.expm1(y_train) * 0.35))
huber_high_price = HuberRegressor(max_iter=2000)
huber_high_price.fit(X_train_overall, np.log1p( np.expm1(y_train) * 0.65))

joblib.dump(huber_true_price, "price_estimator.joblib")
joblib.dump(huber_low_price, "low_price_estimator.joblib")
joblib.dump(huber_high_price, "high_price_estimator.joblib")
# Out:
# ['high_price_estimator.joblib']

# %%
import joblib


def test_models() -> None:
    transformer = joblib.load("ames_transformer.joblib")
    price_reg = joblib.load("price_estimator.joblib")
    low_price_reg = joblib.load("low_price_estimator.joblib")
    high_price_reg = joblib.load("high_price_estimator.joblib")

    # select houses from test set around 25th, 50th and 75th percentile
    prices = np.expm1(y_test).astype(int)

    for price_type, quantile in [
        ("Cheap", 0.25),
        ("Average", 0.5),
        ("Expensive", 0.75),
    ]:
        idx = prices[
            prices == prices.quantile(quantile, interpolation="nearest")
        ].index[0]
        X = X_test_raw.loc[idx].to_frame().T
        y = prices[idx]

        float_to_int = lambda x: int(np.round(np.expm1(x.item())))

        X_transformed = transformer.transform(X)
        y_pred = float_to_int(price_reg.predict(X_transformed))
        y_low_pred = float_to_int(low_price_reg.predict(X_transformed))
        y_high_pred = float_to_int(high_price_reg.predict(X_transformed))

        print(f"{price_type} house")
        print(f"True price: {y}$")
        print(f"Estimated price: {y_pred}")
        print(f"Price brackets: {y_low_pred} - {y_high_pred}")

        print("Features:")
        with pd.option_context("display.max_columns", None):
            display(X)


test_models()
# Out:
# Cheap house
# True price: 127999$
# Estimated price: 133417
# Price brackets: 46690 - 86707
# Features:
#     MSSubClass MSZoning LotFrontage LotArea Street Alley LotShape LandContour  \
# 195       SC50       RM        50.0    6000      2     0        4         Lvl
#
#     Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 195         4    Inside         3      BrkSide       Norm       Norm     1Fam
#
#     HouseStyle OverallQual OverallCond YearBuilt YearRemodAdd RoofStyle  \
# 195     1.5Fin           6           6      1940         1950     Gable
#
#     RoofMatl Exterior1st Exterior2nd MasVnrType MasVnrArea ExterQual  \
# 195  CompShg     MetalSd     MetalSd       None        0.0         3
#
#     ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 195         4     CBlock        3        3            0            2
#
#     BsmtFinSF1 BsmtFinType2 BsmtFinSF2 BsmtUnfSF TotalBsmtSF Heating  \
# 195      264.0            1        0.0     308.0       572.0    GasA
#
#     HeatingQC CentralAir Electrical X1stFlrSF X2ndFlrSF LowQualFinSF  \
# 195         5          Y      FuseA       848       348            0
#
#     GrLivArea BsmtFullBath BsmtHalfBath FullBath HalfBath BedroomAbvGr  \
# 195      1196          0.0          1.0        1        1            3
#
#     KitchenAbvGr KitchenQual TotRmsAbvGrd Functional Fireplaces FireplaceQu  \
# 195            1           3            6          8          2           4
#
#     GarageType GarageYrBlt GarageFinish GarageCars GarageArea GarageQual  \
# 195     Detchd      1973.0          Unf        2.0      576.0          3
#
#     GarageCond PavedDrive WoodDeckSF OpenPorchSF EnclosedPorch X3SsnPorch  \
# 195          3          2          0           0             0          0
#
#     ScreenPorch PoolArea PoolQC Fence MiscFeature MiscVal MoSold YrSold  \
# 195           0        0      0    No          No       0    Mar   2010
#
#     SaleType SaleCondition
# 195      WD         Normal
# Average house
# True price: 157999$
# Estimated price: 151858
# Price brackets: 53155 - 98712
# Features:
#      MSSubClass MSZoning LotFrontage LotArea Street Alley LotShape  \
# 2538       SC80       RL        80.0    9600      2     0        4
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 2538         Lvl         4    Inside         3        NAmes       Norm
#
#      Condition2 BldgType HouseStyle OverallQual OverallCond YearBuilt  \
# 2538       Norm     1Fam       SLvl           5           7      1967
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 2538         1967     Gable  CompShg     MetalSd     MetalSd    BrkFace
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 2538      140.0         3         3      PConc        3        3            2
#
#      BsmtFinType1 BsmtFinSF1 BsmtFinType2 BsmtFinSF2 BsmtUnfSF TotalBsmtSF  \
# 2538            5      602.0            3      402.0     137.0      1141.0
#
#      Heating HeatingQC CentralAir Electrical X1stFlrSF X2ndFlrSF LowQualFinSF  \
# 2538    GasA         4          Y      SBrkr      1141         0            0
#
#      GrLivArea BsmtFullBath BsmtHalfBath FullBath HalfBath BedroomAbvGr  \
# 2538      1141          1.0          0.0        1        0            3
#
#      KitchenAbvGr KitchenQual TotRmsAbvGrd Functional Fireplaces FireplaceQu  \
# 2538            1           3            6          8          0           0
#
#      GarageType GarageYrBlt GarageFinish GarageCars GarageArea GarageQual  \
# 2538     Attchd      1967.0          Unf        1.0      568.0          3
#
#      GarageCond PavedDrive WoodDeckSF OpenPorchSF EnclosedPorch X3SsnPorch  \
# 2538          3          2          0          78             0          0
#
#      ScreenPorch PoolArea PoolQC Fence MiscFeature MiscVal MoSold YrSold  \
# 2538           0        0      0    No          No       0    Jul   2006
#
#      SaleType SaleCondition
# 2538      WD         Normal
# Expensive house
# True price: 209499$
# Estimated price: 190713
# Price brackets: 66734 - 123939
# Features:
#     MSSubClass MSZoning LotFrontage LotArea Street Alley LotShape LandContour  \
# 192       SC75       RL         0.0    7793      2     0        3         Bnk
#
#     Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 192         4    Corner         3      BrkSide       Norm       Norm     1Fam
#
#     HouseStyle OverallQual OverallCond YearBuilt YearRemodAdd RoofStyle  \
# 192     2.5Unf           7           7      1922         2005     Gable
#
#     RoofMatl Exterior1st Exterior2nd MasVnrType MasVnrArea ExterQual  \
# 192  CompShg     Wd Sdng     Wd Sdng       None        0.0         3
#
#     ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 192         3     BrkTil        4        3            0            4
#
#     BsmtFinSF1 BsmtFinType2 BsmtFinSF2 BsmtUnfSF TotalBsmtSF Heating  \
# 192      474.0            1        0.0     634.0      1108.0    GasA
#
#     HeatingQC CentralAir Electrical X1stFlrSF X2ndFlrSF LowQualFinSF  \
# 192         3          N      FuseA      1160       908            0
#
#     GrLivArea BsmtFullBath BsmtHalfBath FullBath HalfBath BedroomAbvGr  \
# 192      2068          0.0          0.0        1        1            3
#
#     KitchenAbvGr KitchenQual TotRmsAbvGrd Functional Fireplaces FireplaceQu  \
# 192            1           4            8          8          1           4
#
#     GarageType GarageYrBlt GarageFinish GarageCars GarageArea GarageQual  \
# 192     Detchd      1928.0          Unf        1.0      315.0          3
#
#     GarageCond PavedDrive WoodDeckSF OpenPorchSF EnclosedPorch X3SsnPorch  \
# 192          3          2          0           0            60          0
#
#     ScreenPorch PoolArea PoolQC Fence MiscFeature MiscVal MoSold YrSold  \
# 192           0        0      0    No          No       0    May   2010
#
#     SaleType SaleCondition
# 192      WD         Normal

# %% [markdown]
# Wybrałem `Huber` bo to prawie `Hubert` i przynosił najlepsze efekty względem czasu

# %% [markdown]
# Modele najlepiej oceniają domy średnie tanie przeceniają delikatnie drogie niedoceniają ale wyniki są okej, jednakże widełki są znacząco zaniżone

# %% [markdown]
# ## Zadanie dodatkowe (3 punkty)

# %% [markdown]
# Product Owner przychodzi do ciebie ponownie. Klienci skarżą się, że nie rozumieją, czemu model przewiduje taką, a nie inną wartość dla ich domu. Przykładowo, jeżeli to ogólny stan domu (`OverallCond`) czy garażu (`GarageCond`) obniżają cenę, to byliby gotowi je wyremontować dla lepszego zysku.
#
# Jest to problem **wyjaśnialnego AI (Explainable AI, XAI)**. O ile cały model w przypadku regresji liniowej jest bardzo transparentny dzięki wagom cech i liniowym predykcjom, to już zrozumienie, czemu dana predykcja była taka, a nie inna, to już problem **lokalnej wyjaśnialności (local explainability)**, gdzie tłumaczymy pojedynczą predykcję, dla danego zestawu cech.
#
# Najpopularniejszym algorytmem jest tutaj **SHapley Additive Explanations (SHAP)**. Opiera się on o tzw. wartości Shapleya, mające bardzo solidne podstawy w kooperatywnej teorii gier. Opiera się na idei, że wartości cech grają w grę: jedne obniżają predykcję, a drugie podwyższają, a finalna predykcja modelu to ich konsekwencja. Każda cecha to gracz, ale jedna wnosi więcej, a inna mniej. Idea algorytmu SHAP to uznanie, że "wartościowi gracze" to wpływowe cechy, które mocno przyczyniły się do danej decyzji modelu.
#
# Obliczanie wartości Shapleya w ogólnym przypadku ma złożoność eksponencjalną. Algorytm SHAP zaproponował efektywne ich przybliżanie dla dowolnych algorytmów ML. Dla niektórych klas modeli, przede wszystkim liniowych oraz drzewiastych, istnieją szczególnie efektywne metody, które w czasie wielomianowym obliczają dokładne wartości Shapleya. Wyjaśnienia, jak działa SHAP: [link 1](https://www.youtube.com/watch?v=9haIOplEIGM), [link 2](https://www.youtube.com/watch?v=VB9uV-x0gtg), [link 3](https://www.youtube.com/watch?v=0yXtdkIL3Xk).
#
# Z pomocą biblioteki `shap` oblicz wartości Shapleya dla przykładowych domów z ostatniego zadania i wyświetl je na tzw. force plot. Przyda ci się tutaj `LinearExplainer` ([dokumentacja](https://shap.readthedocs.io/en/latest/generated/shap.LinearExplainer.html#shap.LinearExplainer)) oraz `plots.force()` ([dokumentacja](https://shap.readthedocs.io/en/latest/generated/shap.plots.force.html)).
#
# Porównaj ze sobą dwie metody estymacji: "interventional" oraz "correlation_dependent" (opisane w dokumentacji). Możesz je zaimplementować za pomocą `maskers.Independent` oraz `maskers.Impute`. Jako zbiór do porównania (tzw. background samples) użyj całego zbioru treningowego.
#
# Skomentuj, czy wyjaśnienia mają twoim zdaniem sens i czy są intuicyjne. Która metoda estymacji daje subiektywnie lepsze wyniki?
